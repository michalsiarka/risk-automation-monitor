# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data/risk_monitor.db')

df = pd.read_sql_query("SELECT * FROM transactions LIMIT 10", conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/dev/RiskMonitorProject/venv/lib/python3.9/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: transactions
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 7
#       4 # Teraz zadziała, bo notatnik i folder 'data' są w tym samym miejscu!
#       5 conn = sqlite3.connect('data/risk_monitor.db')
# ----> 7 df = pd.read_sql_query("SELECT * FROM transactions LIMIT 10", conn)
#       8 df
#
# ...
